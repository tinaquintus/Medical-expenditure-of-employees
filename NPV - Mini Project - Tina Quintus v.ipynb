# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#           <div align="center">
#               <font color="#21618C" size=8px>
#                     <b> NPV - MiniProject  <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings(action='ignore')

# %%
data=pd.read_csv('C:/Users/user/Downloads/Python notebooks/NPV - Mini 2- Question-1/emp_health.csv')
data
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %% [markdown]
# Q1. How many employees above 50 age smoke, what is their average expenditure on health management?

# %%
print('The number of employees who smoke and are above the age 50 :')
df_age_50=data[(data['age']>50) & (data['smoke']=='yes')]['id'].count()
df_age_50
# Out:
# The number of employees who smoke and are above the age 50 :
# 64

# %%
print('Their average expenditure on health management :')
df_age_50=data[(data['age']>50) & (data['smoke']=='yes')]['expenditure'].mean()
df_age_50
# Out:
# Their average expenditure on health management :
# 38820.22308234375

# %% [markdown]
# # Inference:
# The number of employees who smoke and are above the age 50 are 64 employees and their average
# expenditure on health management is Rs.38820.22

# %% [markdown]
# Q2. How many female employees did not consume alcohol daily. What is their proportion with respect to total female employees?

# %%
data[(data['sex']=='female') & (data['alcohol']!='daily')]['id'].count()
# Out:
# 453

# %%
data[data['sex']=='female']['id'].count()
# Out:
# 662

# %% [markdown]
# # Inference :
#     The number of female employees who do not consume alcohol daily are 453 and their proportion with
#     respect to total female employees is 453/662

# %% [markdown]
# Q3. Display zone wise average expenditure of employees on health

# %%
zone_expenditure=pd.DataFrame(data.groupby(by='zone')['expenditure'].mean())
print('Zone wise average expenditure of employees on health :')
zone_expenditure
# Out:
# Zone wise average expenditure of employees on health :
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %% [markdown]
# Q4. Employees of which zone did maximum expenditure on health

# %%
print('The maximum expenditure of all the zones')
zone_expenditure_max=pd.DataFrame(data.groupby(by='zone')['expenditure'].max())
zone_expenditure_max
# Out:
# The maximum expenditure of all the zones
#            expenditure
# zone
# east       58571.07448
# north      48549.17835
# northeast  46255.11250
# northwest  55135.40209
# south      47055.53210
# southeast  63770.42801
# southwest  52590.82939
# west       60021.39897

# %% [markdown]
# # Inference :
#     The employees of Southeast zone has done the maximum expenditure on health
#     Southeast=63770.42801

# %% [markdown]
# Q5. What is the minimum expenditure done by any employee in organization

# %%
zone_expenditure_min=data['expenditure'].min()
zone_expenditure_min
# Out:
# 1121.8739

# %% [markdown]
# # Inference :
#      The minimum expenditure done by any employee in the organization is Rs.1121.8739

# %% [markdown]
# Q6. What is average expenditure of employees who have 2 or lesser dependents

# %%
avg_expenditure_of_dependents=data[(data.dependent<=2)]['expenditure'].mean()
avg_expenditure_of_dependents
# Out:
# 13040.970970948145

# %% [markdown]
# # Inference :
#        The average expenditure of employees who have 2 or lesser dependent is 13040.970970948145

# %% [markdown]
# Q7. How many employees are below age of 20 years. What is their average BMI

# %%
age_employees_below_20=pd.DataFrame(data[data['age']<20])
age_employees_below_20
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 15    i10027   19    male  24.600          1    party    no  southwest
# 22    i10034   18    male  34.100          0    daily    no      south
# 31    i10043   18  female  26.315          0    daily    no      north
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1315  i11327   18    male  28.310          1  weekend    no       east
# 1316  i11328   19  female  20.600          0  weekend    no  southwest
# 1317  i11329   18    male  53.130          0    party    no  southeast
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 15     1837.23700
# 22     1137.01100
# ...

# %%
age_employees_below_20.count()
# Out:
# id             137
# age            137
# sex            137
# bmi            137
# dependent      137
# alcohol        137
# smoke          137
# zone           137
# expenditure    137
# dtype: int64

# %%
age_employees_below_20_BMI=age_employees_below_20['bmi'].mean()
age_employees_below_20_BMI
# Out:
# 29.971496350364966

# %% [markdown]
# # Inference :
#       There are 137 employees who are under the age 20 and their average BMI is 29.971496350364966

# %% [markdown]
# Q8. Create a dataframe "non_smoker" for all non-smoker male employees

# %%
non_smoker=pd.DataFrame(data[(data['smoke']=='no') & (data['sex']=='male')])
non_smoker
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
# # Inference :
#      There are 517 employees in the 'Non-Smoker' DataFrame

# %% [markdown]
# Q9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol

# %%
non_alcoholic=pd.DataFrame(data[(data['alcohol']=='no') & (data['sex']=='male')])
non_alcoholic
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %% [markdown]
# # Inference :
#       There are 147 empoloyees in the 'Non-alcoholic' DataFrame

# %% [markdown]
#  10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol
#  (Hint:Use join and dataframes created in Q8 and Q9)

# %%
non_smoking_alcoholic=pd.merge(non_alcoholic,non_smoker,on=['id', 'age', 'sex', 'bmi', 'dependent', 'alcohol', 'smoke', 'zone',
       'expenditure'],how='inner')
non_smoking_alcoholic
# Out:
#          id  age   sex     bmi  dependent alcohol smoke       zone  \
# 0    i10030   56  male  40.300          0      no    no  southwest
# 1    i10036   37  male  28.025          2      no    no  northwest
# 2    i10040   23  male  17.385          1      no    no  northwest
# 3    i10049   26  male  20.800          0      no    no  southwest
# 4    i10079   40  male  26.315          1      no    no  northwest
# ..      ...  ...   ...     ...        ...     ...   ...        ...
# 104  i11273   28  male  37.100          1      no    no  southwest
# 105  i11282   26  male  33.915          1      no    no       west
# 106  i11322   42  male  26.315          1      no    no       west
# 107  i11332   31  male  31.065          3      no    no       west
# 108  i11345   50  male  30.970          3      no    no       west
#
#      expenditure
# 0    10602.38500
# 1     6203.90175
# 2     2775.19215
# 3     2302.30000
# 4     6389.37785
# ..           ...
# 104   3277.16100
# ...

# %%
non_smoking_alcoholic[['id','alcohol','smoke']]
# Out:
#          id alcohol smoke
# 0    i10030      no    no
# 1    i10036      no    no
# 2    i10040      no    no
# 3    i10049      no    no
# 4    i10079      no    no
# ..      ...     ...   ...
# 104  i11273      no    no
# 105  i11282      no    no
# 106  i11322      no    no
# 107  i11332      no    no
# 108  i11345      no    no
#
# [109 rows x 3 columns]

# %% [markdown]
# # Inference :
#      There are 109 employees who do not consume alcohol and smoke

# %% [markdown]
# Q11.What is the count for each zone with respect to number of dependent

# %%
count_wrt_no_of_dependents=pd.DataFrame(data.groupby('zone')['dependent'].value_counts())
count_wrt_no_of_dependents
# Out:
#                      dependent
# zone      dependent
# east      0                124
#           1                 65
#           2                 42
#           3                 22
#           4                  6
#           5                  3
# north     0                 26
#           1                 20
#           3                 12
#           2                 10
#           4                  1
#           5                  1
# northeast 0                 35
#           2                 15
#           3                 13
#           1                  9
#           4                  2
# northwest 0                 70
#           2                 30
#           1                 28
#           3                 13
#           4                  4
# south     0                 38
#           1                 21
#           2                 12
#           3                 12
#           4                  1
# southeast 0                 81
# ...

# %%
total_count=data.groupby('zone')['dependent'].count()
total_count
# Out:
# zone
# east         262
# north         70
# northeast     74
# northwest    145
# south         84
# southeast    198
# southwest    251
# west         254
# Name: dependent, dtype: int64

# %% [markdown]
# # Inference :
# The count of each zone with respect to the number of dependents in
#
# East :
# dependent and total: 0 =124,1 =65,2 =42,3 =22,4 = 6,5=3
# The total no.of dependent in east is 262
#
# North:
# dependent and total:0=26,1 =20,3=12,4=1,5=1,2=10
# the total no.of dependent in north is 70
#
# NorthEast:
# dependent and total: 0=35, 2= 15,3=13,1= 9 ,4= 2
# the total no.of dependent in northeast is 74
#
# NorthWest:
# dependent and total: 0=70,2=30,1=28,3=13,4=4
# the total no.of dependent in northwest is 145
#
# South :
# dependent and total:0 =38,1=21,2=12,3=12,4=1
# the total no.of dependent in south is 84
#
# SouthEast:
# dependent and total:0= 81,1=57, 2=38,3=15, 5= 5, 4=2
# the total no.of dependent in southeast is 198
#
# SouthWest:
# dependent and total:0 = 116, 1= 53,2=44,3= 25,5=7,4= 6
# the total no.of dependent in SouthWest is 251
#
# West :
# dependent and total: 0= 84,1= 71,2=49,3= 45,4=3,5=2
# the total no.of dependent in West is 254

# %% [markdown]
# Q12. Classify the employees into 3 categories.
#  Category 1 : employees below 18.5 bmi - underweight
#  Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
#  Category 3 : employee with bmi over 24.9 - overweight
#  What is the average expenditure of employees in each category.
#  Display the bar chart for the same

# %%
Category_1=data[data.bmi<18.5]
Category_1
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 28    i10040   23    male  17.385          1       no    no  northwest
# 128   i10140   32  female  17.765          2  weekend   yes  northwest
# 172   i10184   18    male  15.960          0    party    no      north
# 198   i10210   51  female  18.050          0  weekend    no  northwest
# 232   i10244   19  female  17.800          0    party    no  southwest
# 250   i10262   18    male  17.290          2    party   yes      north
# 380   i10392   27  female  17.955          2    party   yes       east
# 410   i10422   19    male  17.480          0  weekend    no       west
# 412   i10424   26  female  17.195          2       no   yes       east
# 428   i10440   21  female  16.815          1    daily    no       east
# 680   i10692   21  female  17.400          1  weekend    no       west
# 821   i10833   26    male  17.670          0       no    no  northwest
# ...

# %%
total_count_of_category_1=Category_1.bmi.count()
total_count_of_category_1
# Out:
# 20

# %%
Category_1_avg_expenditure=Category_1['expenditure'].mean()
Category_1_avg_expenditure
# Out:
# 8852.200585000002

# %%
category_2=data[(data.bmi>=18.5)& (data.bmi<=24.9)]
category_2
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 15    i10027   19    male  24.600          1    party    no  southwest
# 17    i10029   23    male  23.845          0  weekend    no      north
# 26    i10038   63  female  23.085          0  weekend    no      north
# 35    i10047   19    male  20.425          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1304  i11316   42    male  24.605          2    daily   yes       east
# 1306  i11318   29  female  21.850          0  weekend   yes       east
# 1314  i11326   30  female  23.655          3    daily   yes       west
# 1316  i11328   19  female  20.600          0  weekend    no  southwest
# 1328  i11340   23  female  24.225          2  weekend    no       east
#
#       expenditure
# 3     21984.47061
# 15     1837.23700
# 17     2395.17155
# 26    14451.83515
# ...

# %%
total_count_of_category_2=category_2.bmi.count()
total_count_of_category_2
# Out:
# 222

# %%
Category_2_avg_expenditure=category_2['expenditure'].mean()
Category_2_avg_expenditure
# Out:
# 10379.499732162163

# %%
Category_3=data[data.bmi>24.9]
Category_3
# Out:
#           id  age     sex    bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.90          0    daily   yes  southwest
# 1     i10013   18    male  33.77          1  weekend    no      south
# 2     i10014   28    male  33.00          3   rarely    no      south
# 4     i10016   32    male  28.88          0    party    no  northwest
# 5     i10017   31  female  25.74          0       no    no      south
# ...      ...  ...     ...    ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.97          3       no    no       west
# 1334  i11346   18  female  31.92          0    daily    no       east
# 1335  i11347   18  female  36.85          0  weekend    no  southeast
# 1336  i11348   21  female  25.80          0    party    no  southwest
# 1337  i11349   61  female  29.07          0       no   yes       west
#
#       expenditure
# 0      16884.9240
# 1       1725.5523
# 2       4449.4620
# 4       3866.8552
# 5       3756.6216
# ...

# %%
total_count_of_category_3=Category_3.bmi.count()
total_count_of_category_3
# Out:
# 1096

# %%
Category_3_avg_expenditure=Category_3['expenditure'].mean()
Category_3_avg_expenditure
# Out:
# 13936.616823466235

# %%
plt.bar(x=['category_1','category_2','category_3'],height=[8852.200585000002,10379.499732162163,13936.616823466235])
plt.title('Average expenditure of employees in each category')
plt.xlabel('Types of Categories')
plt.ylabel('Average Expenditure')
plt.show()

# %% [markdown]
# # Inference :
# Category 1 : employees below 18.5 bmi - underweight is 20
#
# Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit is 222
#
# Category 3 : employee with bmi over 24.9 - overweight is 1096
#
# The average expenditure of employees in each category is
#
# category 1=8852.200585000002
#
# category 2=10379.499732162163
#
# category 3=13936.616823466235

# %% [markdown]
# Q13. Draw line plot of expenditure against age and BMI

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='age',y='expenditure',hue='smoke',data=data);

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='bmi',y='expenditure',hue='smoke',data=data);

# %% [markdown]
# Q14. Draw a bar chart to show zone wise average expenditure

# %%
data
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
bar1=data.groupby('zone')['expenditure'].mean()
bar2=bar1.to_frame()
bar2
# Out:
#             expenditure
# zone
# east       13774.679941
# north      14102.583403
# northeast  13694.721724
# northwest  12151.702619
# south      14715.689519
# southeast  14452.949680
# southwest  12717.083869
# west       12182.998872

# %%
plt.figure(figsize=(9,5))
plt.bar(x=bar2.index,height=bar2['expenditure'])
plt.title('Average Expenditure of each zone')
plt.xlabel('Zones')
plt.ylabel('Average Expenditure')
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.barplot(x='zone',y='expenditure',data=data)
# Out:
# <AxesSubplot:xlabel='zone', ylabel='expenditure'>

# %% [markdown]
# Q15. Draw a bar chart to show smoking and alcoholic habits against average expenditure

# %%
expenditure1=data.groupby('alcohol')['expenditure'].mean()
expenditure1=expenditure1.to_frame()
expenditure1
# Out:
#           expenditure
# alcohol
# daily    13001.772968
# no       14277.090885
# party    13050.583157
# rarely   12419.686784
# weekend  13145.632539

# %%
expenditure2=data.groupby('smoke')['expenditure'].mean()
expenditure2=expenditure2.to_frame()
expenditure2
# Out:
#         expenditure
# smoke
# no      8434.268298
# yes    32050.231832

# %%
exp1.plot.bar()
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
sns.barplot(x='alcohol',y='expenditure',data=data)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='expenditure'>

# %%
sns.barplot(x='smoke',y='expenditure',data=data)
# Out:
# <AxesSubplot:xlabel='smoke', ylabel='expenditure'>

# %% [markdown]
# Q16. Draw pie chart for alcohol consumption habits

# %%
alcohol_consumption_habits=data['alcohol'].value_counts()
alcohol_consumption_habits.to_frame()
# Out:
#          alcohol
# daily        395
# weekend      347
# party        278
# no           259
# rarely        59

# %%
plt.figure(figsize=(7,6))
consumption=['daily','weekend','party','no','rarely']
plt.pie(a,labels=consumption,autopct='%1.2f%%' );
plt.title('Alcohol Consumption Habits')
plt.show()

# %% [markdown]
# Q17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue

# %%
sns.scatterplot(x=data.expenditure,y=data.age,hue=data.smoke);

# %% [markdown]
# Q18. Draw distribution plot of expenditure

# %%
sns.distplot(data.expenditure);

# %% [markdown]
# Q19. Display the pairplot

# %%
sns.pairplot(data[['id','age','sex','bmi','dependent','alcohol','smoke','zone','expenditure']]);

# %% [markdown]
# Q20. Display heatmap for the data

# %%
plt.figure(figsize=(7,6))
sns.heatmap(data.corr(),annot=True,cmap='Blues');
